# %% [markdown]
# <a href="https://colab.research.google.com/github/19pa1a0451/Gollapudi-sandeep/blob/master/legends.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**#AVOCADO PRICES DATASET#**#
#
# #**INTRODUCTION:**
#
# The dataset choosen in below gives the information regarding avocado prices.
#
# **Variables:**
#
# 1.Date-The coloumn represents the data collection of avocado in that date.
#
# 2.Average prices- The coloumn represents the average price of the avocado.
#
# 3.Total volume- The coloumn represents the total volume of the avocado.
#
# 4.4046-The coloumn used for the code of avacados fruit.
#
# 5.4225-The coloumn used for the code of avacados fruit.
#
# 6.4770-The coloumn used for the code of avacados fruit.
#
# 7.Total bags-The coloumn represents the total bags of the avacado.
#
# 8.Small bags-The coloumn represents the small bags that containing avacado.
#
# 9.Large bags-The coloumn represents the large that containing avacado.
#
# 10.Xlarge bags-The coloumn represents the maximum quantity of the bags that containing avacado.
#
# 11.Type-The coloumn is used to find the type of the avacado.
#
# 12.Year- the coloumn represents the price of avacado in the year.
#
# 13.Region-The coloumn represents the region that selling of avacado.

# %% [markdown]
# #**Questions:**
#
# **1.check the data dimensions of the dataset?**
#
# **2.Find the transpose of the dataframes?**
#
# **3.what is the output when we set AveragePrice as row index?**
#
# **4.Flow many total bags of Avacado sold on 2015-12-20?**
#
# **5.Generate various summary statistics for every coloumn of given dataset?**

# %% [markdown]
# **data**

# %%
m
# Out:
#        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %% [markdown]
# #**#Reading the dataset.**

# %%
import pandas as pd
m=pd.read_csv("m")
m
# Out:
#        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %% [markdown]
# #**#Showing first n row.**

# %%
m.head(11000)
# Out:
#        Unnamed: 0        Date  AveragePrice  ...          type  year    region
# 0               0  2015-12-27          1.33  ...  conventional  2015    Albany
# 1               1  2015-12-20          1.35  ...  conventional  2015    Albany
# 2               2  2015-12-13          0.93  ...  conventional  2015    Albany
# 3               3  2015-12-06          1.08  ...  conventional  2015    Albany
# 4               4  2015-11-29          1.28  ...  conventional  2015    Albany
# ...           ...         ...           ...  ...           ...   ...       ...
# 10995          49  2015-01-18          1.80  ...       organic  2015    Plains
# 10996          50  2015-01-11          1.68  ...       organic  2015    Plains
# 10997          51  2015-01-04          1.69  ...       organic  2015    Plains
# 10998           0  2015-12-27          1.24  ...       organic  2015  Portland
# 10999           1  2015-12-20          1.21  ...       organic  2015  Portland
#
# ...

# %% [markdown]
# #**#Delete given row or column.pass axis=1 for column.**

# %%
m.drop(100)
# Out:
#        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [18248 rows x 14 columns]

# %% [markdown]
# #**#Resent index,putting old index in column named index.**

# %%
m.reset_index()
# Out:
#        index  Unnamed: 0        Date  ...          type  year            region
# 0          0           0  2015-12-27  ...  conventional  2015            Albany
# 1          1           1  2015-12-20  ...  conventional  2015            Albany
# 2          2           2  2015-12-13  ...  conventional  2015            Albany
# 3          3           3  2015-12-06  ...  conventional  2015            Albany
# 4          4           4  2015-11-29  ...  conventional  2015            Albany
# ...      ...         ...         ...  ...           ...   ...               ...
# 18244  18244           7  2018-02-04  ...       organic  2018  WestTexNewMexico
# 18245  18245           8  2018-01-28  ...       organic  2018  WestTexNewMexico
# 18246  18246           9  2018-01-21  ...       organic  2018  WestTexNewMexico
# 18247  18247          10  2018-01-14  ...       organic  2018  WestTexNewMexico
# 18248  18248          11  2018-01-07  ...       organic  2018  WestTexNewMexico
#
# ...

# %% [markdown]
# #**#Transpose dataframe.**

# %%
m.T
# Out:
#                      0             1      ...             18247             18248
# Unnamed: 0               0             1  ...                10                11
# Date            2015-12-27    2015-12-20  ...        2018-01-14        2018-01-07
# AveragePrice          1.33          1.35  ...              1.93              1.62
# Total Volume       64236.6         54877  ...           16205.2           17489.6
# 4046               1036.74        674.28  ...           1527.63           2894.77
# 4225               54454.8       44638.8  ...           2981.04           2356.13
# 4770                 48.16         58.33  ...            727.01            224.53
# Total Bags         8696.87       9505.56  ...           10969.5           12014.1
# Small Bags         8603.62       9408.07  ...           10919.5           11988.1
# Large Bags           93.25         97.49  ...                50             26.01
# ...

# %% [markdown]
# #**#Change lowest level of column labels into innermost row index.**

# %%
m.stack()
# Out:
# 0      Unnamed: 0                     0
#        Date                  2015-12-27
#        AveragePrice                1.33
#        Total Volume             64236.6
#        4046                     1036.74
#                              ...
# 18248  Large Bags                 26.01
#        XLarge Bags                    0
#        type                     organic
#        year                        2018
#        region          WestTexNewMexico
# Length: 255486, dtype: object

# %% [markdown]
# #**#Change innermost row index into lowest level of column label.**

# %%
m.unstack()
# Out:
# Unnamed: 0  0                       0
#             1                       1
#             2                       2
#             3                       3
#             4                       4
#                            ...
# region      18244    WestTexNewMexico
#             18245    WestTexNewMexico
#             18246    WestTexNewMexico
#             18247    WestTexNewMexico
#             18248    WestTexNewMexico
# Length: 255486, dtype: object

# %% [markdown]
# #**#Drops rows where any data is missing.**

# %%
m.dropna()
# Out:
#        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %% [markdown]
# #**#Return maximum of every column.**

# %%
m.max()
# Out:
# Unnamed: 0                    52
# Date                  2018-03-25
# AveragePrice                3.25
# Total Volume         6.25056e+07
# 4046                 2.27436e+07
# 4225                 2.04706e+07
# 4770                 2.54644e+06
# Total Bags           1.93731e+07
# Small Bags           1.33846e+07
# Large Bags            5.7191e+06
# XLarge Bags               551694
# type                     organic
# year                        2018
# region          WestTexNewMexico
# dtype: object

# %% [markdown]
# #**#Return mimimum of every column.**

# %%
m.min()
# Out:
# Unnamed: 0                 0
# Date              2015-01-04
# AveragePrice            0.44
# Total Volume           84.56
# 4046                       0
# 4225                       0
# 4770                       0
# Total Bags                 0
# Small Bags                 0
# Large Bags                 0
# XLarge Bags                0
# type            conventional
# year                    2015
# region                Albany
# dtype: object

# %% [markdown]
# #**#Generate various summary statistics for every column.**

# %%
m.describe()
# Out:
#          Unnamed: 0  AveragePrice  ...    XLarge Bags          year
# count  18249.000000  18249.000000  ...   18249.000000  18249.000000
# mean      24.232232      1.405978  ...    3106.426507   2016.147899
# std       15.481045      0.402677  ...   17692.894652      0.939938
# min        0.000000      0.440000  ...       0.000000   2015.000000
# 25%       10.000000      1.100000  ...       0.000000   2015.000000
# 50%       24.000000      1.370000  ...       0.000000   2016.000000
# 75%       38.000000      1.660000  ...     132.500000   2017.000000
# max       52.000000      3.250000  ...  551693.650000   2018.000000
#
# [8 rows x 11 columns]

# %% [markdown]
# #**#information about dataset** *italicized text*

# %%
m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
# Unnamed: 0      18249 non-null int64
# Date            18249 non-null object
# AveragePrice    18249 non-null float64
# Total Volume    18249 non-null float64
# 4046            18249 non-null float64
# 4225            18249 non-null float64
# 4770            18249 non-null float64
# Total Bags      18249 non-null float64
# Small Bags      18249 non-null float64
# Large Bags      18249 non-null float64
# XLarge Bags     18249 non-null float64
# type            18249 non-null object
# year            18249 non-null int64
# region          18249 non-null object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# #**#correletion**

# %%
m.corr()
# Out:
#               Unnamed: 0  AveragePrice  ...  XLarge Bags      year
# Unnamed: 0      1.000000     -0.133008  ...    -0.011546 -0.171667
# AveragePrice   -0.133008      1.000000  ...    -0.117592  0.093197
# Total Volume    0.014035     -0.192752  ...     0.747157  0.017193
# 4046            0.017628     -0.208317  ...     0.699377  0.003353
# 4225            0.019829     -0.172928  ...     0.688809 -0.009559
# 4770            0.041752     -0.179446  ...     0.679861 -0.036531
# Total Bags     -0.002219     -0.177088  ...     0.804233  0.071552
# Small Bags      0.000347     -0.174730  ...     0.806845  0.063915
# Large Bags     -0.009196     -0.172940  ...     0.710858  0.087891
# XLarge Bags    -0.011546     -0.117592  ...     1.000000  0.081033
# year           -0.171667      0.093197  ...     0.081033  1.000000
#
# [11 rows x 11 columns]

# %% [markdown]
# #**#variance**

# %%
m.var()
# Out:
# Unnamed: 0      2.396627e+02
# AveragePrice    1.621484e-01
# Total Volume    1.192698e+13
# 4046            1.600197e+12
# 4225            1.449906e+12
# 4770            1.154853e+10
# Total Bags      9.726741e+11
# Small Bags      5.567824e+11
# Large Bags      5.951939e+10
# XLarge Bags     3.130385e+08
# year            8.834843e-01
# dtype: float64

# %% [markdown]
# #**#Add dataframes**

# %%
m.sub
# Out:
# <bound method _arith_method_FRAME.<locals>.f of        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]>

# %% [markdown]
# #**#subtract dataframes**

# %%
m.add
# Out:
# <bound method _arith_method_FRAME.<locals>.f of        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]>

# %% [markdown]
# #**#multiply dataframes**

# %%
m.mul
# Out:
# <bound method _arith_method_FRAME.<locals>.f of        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]>

# %% [markdown]
# #**#divide dataframes(float division)**

# %%
m.div
# Out:
# <bound method _arith_method_FRAME.<locals>.f of        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]>

# %% [markdown]
# #**#divide dataframes(float division)**

# %%
m.truediv
# Out:
# <bound method _arith_method_FRAME.<locals>.f of        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]>

# %% [markdown]
# #**#calculate modulo(integer division)**

# %%
m.mod
# Out:
# <bound method _arith_method_FRAME.<locals>.f of        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]>

# %% [markdown]
# #**#counting missing values**

# %%
m.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# #**#covariance**

# %%
 m.cov()
# Out:
#                  Unnamed: 0   AveragePrice  ...   XLarge Bags          year
# Unnamed: 0       239.662747      -0.829154  ... -3.162427e+03     -2.497961
# AveragePrice      -0.829154       0.162148  ... -8.377831e+02      0.035274
# Total Volume  750396.607100 -268053.371641  ...  4.565372e+10  55810.254638
# 4046          345212.144249 -106112.839423  ...  1.565299e+10   3987.170132
# 4225          369635.513087  -83847.671587  ...  1.467464e+10 -10818.947174
# 4770           69460.271783   -7765.212885  ...  1.292654e+09  -3689.946549
# Total Bags    -33885.242353  -70328.114110  ...  1.403344e+10  66329.581266
# Small Bags      4007.832979  -52500.812494  ...  1.065201e+10  44827.328787
# Large Bags    -34730.638168  -16989.518346  ...  3.068395e+09  20154.653415
# XLarge Bags    -3162.426750    -837.783149  ...  3.130385e+08   1347.598787
# year              -2.497961       0.035274  ...  1.347599e+03      0.883484
#
# [11 rows x 11 columns]

# %% [markdown]
# #**#Delta degrees of freedom**

# %%
m.std(ddof=1)
# Out:
# Unnamed: 0      1.548104e+01
# AveragePrice    4.026766e-01
# Total Volume    3.453545e+06
# 4046            1.264989e+06
# 4225            1.204120e+06
# 4770            1.074641e+05
# Total Bags      9.862424e+05
# Small Bags      7.461785e+05
# Large Bags      2.439660e+05
# XLarge Bags     1.769289e+04
# year            9.399385e-01
# dtype: float64

# %% [markdown]
# #**#Mean**

# %%
m.mean()
# Out:
# Unnamed: 0          24.232232
# AveragePrice         1.405978
# Total Volume    850644.013009
# 4046            293008.424531
# 4225            295154.568356
# 4770             22839.735993
# Total Bags      239639.202060
# Small Bags      182194.686696
# Large Bags       54338.088145
# XLarge Bags       3106.426507
# year              2016.147899
# dtype: float64

# %% [markdown]
# #**#To replace null values in dataframe**

# %%
c = m.fillna(0)
c
# Out:
#        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %% [markdown]
# #**#GRAPHICAL REPRESENTATION**

# %%
import seaborn as sns

# %% [markdown]
# #**Axisgrid.Facegrid**

# %%
sns.relplot(x='AveragePrice',y='Total Volume',hue='4046',data=m)

# %% [markdown]
# #**histogram**

# %%
import matplotlib.pyplot as plt
count_pop =  m.groupby('AveragePrice')['Total Volume'].mean()
count_pop.plot(kind = 'hist')
plt.show()

# %%
point_rate=m.groupby('4046')['4770'].mean()
point_rate.plot()
plt.xlabel('4046')
plt.ylabel('4770')
plt.title('AveragePrice')
plt.show()

# %% [markdown]
# #**plotting of graph**

# %%
m.plot()

# %% [markdown]
# #**bar graph**

# %%
m.plot(x="AveragePrice",y="Total Volume",kind="bar")

# %% [markdown]
# #**A pairwise relationships in the dataset**

# %%
sns.pairplot(data=m)

# %% [markdown]
# #**scatter graph**

# %%
m.plot(x="AveragePrice",y="Total Volume",kind="scatter")

# %% [markdown]
# #**box graph**

# %%
m.plot(x="AveragePrice",y="Total Volume",kind="box")

# %% [markdown]
# #**#Team members#**
# **Gollapudi Sandeep       -19pa1a0451**
#
# **Goraparthi Usha         -19pa1a0452**
#
# **Gorty S.l.N.V.S.Sindhuja-19pa1a0453**
#
# **Dampanaboyina Praneetha -19pa1a0435**
#
# **Inala Sravanthi         -19pa1a0459**
